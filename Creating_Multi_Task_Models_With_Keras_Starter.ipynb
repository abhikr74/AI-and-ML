# %% [markdown]
# <a href="https://colab.research.google.com/github/abhikr74/AI-and-ML/blob/main/Creating_Multi_Task_Models_With_Keras_Starter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Task 1: Introduction
#
# Starter notebook for the Coursera Guided Project [Creating Multi Task Models With Keras](https://www.coursera.org/projects/multi-task-models-keras)

# %%
# %matplotlib inline
# %load_ext tensorboard

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import shutil

try:
  shutil.rmtree('logs')
except:
  pass
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [markdown]
# ## Task 2: Create Dataset

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
def create_example(x,y):
  c =np.random.randint(0,2)
  image = 0.5 * np.random.rand(28,28,3)
  image[:,:,c] += 0.5 * x/255.
  return image, y, c

# %%
colors = {0 :"red", 1:"green"}
x, y, c = create_example(x_train[0], y_train[0])
print(f"digit: {y}, color: {colors[c]}")
plt.imshow(x)
plt.show()
# Out:
# digit: 5, color: green

# %% [markdown]
# ## Task 3: Dataset Generator

# %%
def generate_data(x,y, batch_size=32):
  num_examples = len(y)

  while True:
    x_batch = np.zeros((batch_size, 28, 28, 3))
    y_batch = np.zeros((batch_size,))
    c_batch = np.zeros((batch_size,))

    for i in range(0, batch_size):
      index = np.random.randint(0, num_examples)
      image, digit, color = create_example(x[index], y[index])
      x_batch[i] = image
      y_batch[i] = digit
      c_batch[i] = color

    yield x_batch, [y_batch, c_batch]

# %%
x, [y, c] = next(generate_data(x_test, y_test, batch_size=1))

# %%
print(y, c)
plt.imshow(x[0])
plt.show
# Out:
# [5.] [0.]
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Task 4: Create Model

# %%
from tensorflow.keras.layers import Input, Conv2D, Activation, MaxPool2D, Flatten, Add, Dense

input_ = Input(shape = (28,28,3), name = 'input')

conv_1 = Conv2D(32, 3, name = 'conv_1')(input_)
act_1 = Activation('relu', name = 'act_1')(conv_1)
pool_1 = MaxPool2D(4, name = 'pool_1')(act_1)
flat_1 = Flatten(name = 'flat_1')(pool_1)

color = Dense(1, activation = 'sigmoid', name = 'color')(flat_1)

conv_2 = Conv2D(32, 3, padding = 'same', name = 'conv_2')(act_1)
act_2 = Activation('relu', name = 'act_2')(conv_2)

conv_3 = Conv2D(32, 3, padding = 'same', name = 'conv_3')(act_2)
add = Add(name = 'add')([act_1, conv_3])
act_3 = Activation('relu', name = 'act_3')(add)

pool_2 = MaxPool2D(4, name = 'pool_2')(act_3)
flat_2 = Flatten(name ='flat_2')(pool_2)

digit = Dense(10, activation ="softmax", name = 'digit')(flat_2)

model = tf.keras.models.Model(input_, [digit, color])

model.compile(
    loss = {'digit': 'sparse_categorical_crossentropy',
            'color': 'binary_crossentropy'
            },

    optimizer = 'adam',
    metrics = ['accuracy']

)

model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 28, 28, 3)]  0
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 26, 26, 32)   896         input[0][0]
# __________________________________________________________________________________________________
# act_1 (Activation)              (None, 26, 26, 32)   0           conv_1[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 26, 26, 32)   9248        act_1[0][0]
# __________________________________________________________________________________________________
# act_2 (Activation)              (None, 26, 26, 32)   0           conv_2[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, 26, 26, 32)   9248        act_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 26, 26, 32)   0           act_1[0][0]
#                                                                  conv_3[0][0]
# __________________________________________________________________________________________________
# act_3 (Activation)              (None, 26, 26, 32)   0           add[0][0]
# __________________________________________________________________________________________________
# pool_2 (MaxPooling2D)           (None, 6, 6, 32)     0           act_3[0][0]
# __________________________________________________________________________________________________
# pool_1 (MaxPooling2D)           (None, 6, 6, 32)     0           act_1[0][0]
# __________________________________________________________________________________________________
# flat_2 (Flatten)                (None, 1152)         0           pool_2[0][0]
# __________________________________________________________________________________________________
# flat_1 (Flatten)                (None, 1152)         0           pool_1[0][0]
# __________________________________________________________________________________________________
# digit (Dense)                   (None, 10)           11530       flat_2[0][0]
# __________________________________________________________________________________________________
# color (Dense)                   (None, 1)            1153        flat_1[0][0]
# ==================================================================================================
# Total params: 32,075
# Trainable params: 32,075
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %% [markdown]
# ## Task 5: Training the Model

# %%
class Logger(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs=None):
    digit_accuracy = logs.get('digit_accuracy')
    color_accuracy = logs.get('color_accuracy')
    val_digit_accuracy = logs.get('val_digit_accuracy')
    val_color_accuracy = logs.get('val_color_accuracy')
    print('='*30, epoch + 1, '='*30)
    print(f'digit_accuracy: {digit_accuracy:.2f}, color_accuracy: {color_accuracy:.2f}')
    print(f'val_digit_accuracy: {val_digit_accuracy:.2f}, val_color_accuracy: {val_color_accuracy:.2f}')

# %%
train_gen = generate_data(x_train, y_train)
test_gen = generate_data(x_test, y_test)

_ = model.fit(
    train_gen,
    validation_data = test_gen,
    steps_per_epoch = 200,
    validation_steps = 100,
    epochs = 10,
    callbacks = [
                 Logger(),
                 tf.keras.callbacks.TensorBoard(log_dir= './logs')
    ],
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 1/10
#   3/200 [..............................] - ETA: 1:17 - loss: 3.0378 - digit_loss: 2.3394 - color_loss: 0.6983 - digit_accuracy: 0.0833 - color_accuracy: 0.5000WARNING:tensorflow:Callback method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0079s vs `on_train_batch_begin` time: 0.0857s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0079s vs `on_train_batch_end` time: 0.0429s). Check your callbacks.
# 200/200 [==============================] - 35s 16ms/step - loss: 1.4302 - digit_loss: 1.2604 - color_loss: 0.1698 - digit_accuracy: 0.5670 - color_accuracy: 0.9766 - val_loss: 0.5249 - val_digit_loss: 0.5115 - val_color_loss: 0.0134 - val_digit_accuracy: 0.8406 - val_color_accuracy: 1.0000
# ============================== 1 ==============================
# digit_accuracy: 0.57, color_accuracy: 0.98
# val_digit_accuracy: 0.84, val_color_accuracy: 1.00
# Epoch 2/10
# 200/200 [==============================] - 2s 11ms/step - loss: 0.4223 - digit_loss: 0.4149 - color_loss: 0.0074 - digit_accuracy: 0.8714 - color_accuracy: 1.0000 - val_loss: 0.3117 - val_digit_loss: 0.3073 - val_color_loss: 0.0044 - val_digit_accuracy: 0.9087 - val_color_accuracy: 1.0000
# ============================== 2 ==============================
# digit_accuracy: 0.87, color_accuracy: 1.00
# val_digit_accuracy: 0.91, val_color_accuracy: 1.00
# Epoch 3/10
# 200/200 [==============================] - 2s 10ms/step - loss: 0.2747 - digit_loss: 0.2714 - color_loss: 0.0033 - digit_accuracy: 0.9203 - color_accuracy: 1.0000 - val_loss: 0.2157 - val_digit_loss: 0.2138 - val_color_loss: 0.0020 - val_digit_accuracy: 0.9372 - val_color_accuracy: 1.0000
# ============================== 3 ==============================
# digit_accuracy: 0.92, color_accuracy: 1.00
# val_digit_accuracy: 0.94, val_color_accuracy: 1.00
# Epoch 4/10
# 200/200 [==============================] - 2s 10ms/step - loss: 0.1800 - digit_loss: 0.1784 - color_loss: 0.0016 - digit_accuracy: 0.9413 - color_accuracy: 1.0000 - val_loss: 0.1557 - val_digit_loss: 0.1546 - val_color_loss: 0.0012 - val_digit_accuracy: 0.9559 - val_color_accuracy: 1.0000
# ============================== 4 ==============================
# digit_accuracy: 0.94, color_accuracy: 1.00
# val_digit_accuracy: 0.96, val_color_accuracy: 1.00
# Epoch 5/10
# 200/200 [==============================] - 2s 10ms/step - loss: 0.1751 - digit_loss: 0.1741 - color_loss: 9.9877e-04 - digit_accuracy: 0.9453 - color_accuracy: 1.0000 - val_loss: 0.1306 - val_digit_loss: 0.1298 - val_color_loss: 7.9234e-04 - val_digit_accuracy: 0.9622 - val_color_accuracy: 1.0000
# ============================== 5 ==============================
# digit_accuracy: 0.95, color_accuracy: 1.00
# val_digit_accuracy: 0.96, val_color_accuracy: 1.00
# Epoch 6/10
# 200/200 [==============================] - 2s 10ms/step - loss: 0.1502 - digit_loss: 0.1493 - color_loss: 8.8498e-04 - digit_accuracy: 0.9523 - color_accuracy: 1.0000 - val_loss: 0.1328 - val_digit_loss: 0.1323 - val_color_loss: 5.5499e-04 - val_digit_accuracy: 0.9547 - val_color_accuracy: 1.0000
# ============================== 6 ==============================
# digit_accuracy: 0.95, color_accuracy: 1.00
# val_digit_accuracy: 0.95, val_color_accuracy: 1.00
# Epoch 7/10
# 200/200 [==============================] - 2s 11ms/step - loss: 0.1348 - digit_loss: 0.1341 - color_loss: 6.6402e-04 - digit_accuracy: 0.9570 - color_accuracy: 1.0000 - val_loss: 0.1268 - val_digit_loss: 0.1262 - val_color_loss: 5.5865e-04 - val_digit_accuracy: 0.9597 - val_color_accuracy: 1.0000
# ============================== 7 ==============================
# digit_accuracy: 0.96, color_accuracy: 1.00
# val_digit_accuracy: 0.96, val_color_accuracy: 1.00
# Epoch 8/10
# 200/200 [==============================] - 2s 10ms/step - loss: 0.1247 - digit_loss: 0.1243 - color_loss: 4.7582e-04 - digit_accuracy: 0.9598 - color_accuracy: 1.0000 - val_loss: 0.1220 - val_digit_loss: 0.1217 - val_color_loss: 3.5678e-04 - val_digit_accuracy: 0.9625 - val_color_accuracy: 1.0000
# ============================== 8 ==============================
# digit_accuracy: 0.96, color_accuracy: 1.00
# val_digit_accuracy: 0.96, val_color_accuracy: 1.00
# Epoch 9/10
# 200/200 [==============================] - 2s 11ms/step - loss: 0.1129 - digit_loss: 0.1125 - color_loss: 4.1276e-04 - digit_accuracy: 0.9648 - color_accuracy: 1.0000 - val_loss: 0.1333 - val_digit_loss: 0.1329 - val_color_loss: 4.5796e-04 - val_digit_accuracy: 0.9569 - val_color_accuracy: 1.0000
# ============================== 9 ==============================
# digit_accuracy: 0.96, color_accuracy: 1.00
# val_digit_accuracy: 0.96, val_color_accuracy: 1.00
# Epoch 10/10
# 200/200 [==============================] - 2s 10ms/step - loss: 0.1162 - digit_loss: 0.1158 - color_loss: 3.7692e-04 - digit_accuracy: 0.9634 - color_accuracy: 1.0000 - val_loss: 0.0984 - val_digit_loss: 0.0981 - val_color_loss: 2.5855e-04 - val_digit_accuracy: 0.9688 - val_color_accuracy: 1.0000
# ============================== 10 ==============================
# digit_accuracy: 0.96, color_accuracy: 1.00
# val_digit_accuracy: 0.97, val_color_accuracy: 1.00

# %%
# %tensorboard --logdir logs
# Out:
# Reusing TensorBoard on port 6006 (pid 887), started 0:00:31 ago. (Use '!kill 887' to kill it.)

# %% [markdown]
# ## Task 6: Final Predictions

# %%
def test_model(show=True):
  x, [y, c] = next(test)
  
  preds = model.predict(x)
  pred_digit = np.argmax(preds[0])
  pred_color = int(preds[1] > 0.5)
  gt_digit = int(y[0])
  gt_color = int(c[0])
  
  plt.imshow(x[0])
  if show:
    print(f'GT: {gt_digit}, {colors[gt_color]}')
    print(f'Pr: {pred_digit}, {colors[pred_color]}')
    plt.show()
  else:
    col = 'green' if gt_digit == pred_digit and gt_color == pred_color else 'red'
    plt.ylabel(f'GT: {gt_digit}, {colors[gt_color]}', color=col)
    plt.xlabel(f'Pr: {pred_digit}, {colors[pred_color]}', color=col)
    plt.xticks([])
    plt.yticks([])


test = generate_data(x_test, y_test, batch_size=1)

# %%
test_model()
# Out:
# GT: 1, red
# Pr: 1, red

# %%
plt.figure(figsize=(12,12))
for i in range(0,16):
  plt.subplot(4,4,i+1)
  test_model(show = False)
plt.show()
